# %%
from datetime import datetime, timedelta

import pandas as pd

# %%
date = datetime(2022, 10, 11, 12)
dt = timedelta(minutes=20)
sdate = date - dt
edate = date + dt

df = pd.read_csv('http://mesonet.agron.iastate.edu/cgi-bin/request/asos.py?data=all&tz=Etc/UTC&format=comma&latlon=yes&'
                 f'year1={sdate.year}&month1={sdate.month}&day1={sdate.day}&hour1={sdate.hour}&minute1={sdate.minute}&'
                 f'year2={edate.year}&month2={edate.month}&day2={edate.day}&hour2={edate.hour}&minute2={edate.minute}',
                 skiprows=5, na_values=['M']).replace('T', 0.00001)

# %%
df
# Out:
#       station             valid       lon      lat  tmpf  dwpf    relh   drct  \
# 0        PASK  2022-10-11 11:40 -159.9857  66.6001  28.4  28.4  100.00  230.0
# 1         QEN  2022-10-11 11:40  128.7500  37.6667   NaN   NaN     NaN  270.0
# 2         QEQ  2022-10-11 11:40  127.5500  37.8500  46.4  44.6   93.40   40.0
# 3         QEW  2022-10-11 11:40  128.1500  36.4000  51.8  44.6   76.34   20.0
# 4         QEP  2022-10-11 11:40  127.2667  37.4000  48.2  44.6   87.28    0.0
# ...       ...               ...       ...      ...   ...   ...     ...    ...
# 13477     IJD  2022-10-11 12:19  -72.1836  41.7419  41.0  41.0  100.00    0.0
# 13478     FME  2022-10-11 12:19  -76.7594  39.0854  39.2  37.4   93.19    0.0
# 13479    PAIM  2022-10-11 12:19 -153.7038  65.9928  24.8  15.8   68.18  270.0
# 13480    ETSN  2022-10-11 12:19   11.2115  48.7110  60.8  53.6   77.14   10.0
# 13481     RGA  2022-10-11 12:19  -84.3324  37.6315  39.2  39.2  100.00    0.0
#
#        sknt    p01i  ...  wxcodes  ice_accretion_1hr  ice_accretion_3hr  \
# 0      11.0  0.0001  ...   -SN BR                NaN                NaN
# 1       7.0  0.0000  ...      NaN                NaN                NaN
# 2       2.0  0.0000  ...      NaN                NaN                NaN
# 3       2.0  0.0000  ...      NaN                NaN                NaN
# 4       0.0  0.0000  ...      NaN                NaN                NaN
# ...     ...     ...  ...      ...                ...                ...
# 13477   0.0  0.0000  ...       BR                NaN                NaN
# 13478   0.0  0.0000  ...      NaN                NaN                NaN
# 13479   3.0  0.0000  ...      NaN                NaN                NaN
# 13480   1.0  0.0000  ...      NaN                NaN                NaN
# 13481   0.0  0.0000  ...      NaN                NaN                NaN
#
#        ice_accretion_6hr peak_wind_gust peak_wind_drct peak_wind_time   feel  \
# 0                    NaN            NaN            NaN            NaN  17.92
# 1                    NaN            NaN            NaN            NaN    NaN
# 2                    NaN            NaN            NaN            NaN  46.40
# 3                    NaN            NaN            NaN            NaN  51.80
# 4                    NaN            NaN            NaN            NaN  48.20
# ...                  ...            ...            ...            ...    ...
# 13477                NaN            NaN            NaN            NaN  41.00
# 13478                NaN            NaN            NaN            NaN  39.20
# 13479                NaN            NaN            NaN            NaN  20.46
# 13480                NaN            NaN            NaN            NaN  60.80
# 13481                NaN            NaN            NaN            NaN  39.20
#
#                                                    metar  snowdepth
# 0      PASK 111140Z AUTO 23011KT 5SM -SN BR BKN007 OV...        NaN
# 1      KQEN 111140Z AUTO 27007KT 9999 // CLR / / RMK ...        NaN
# 2      KQEQ 111140Z AUTO 04002KT 9999 CLR 08/07 A3027...        NaN
# 3      KQEW 111140Z AUTO 02002KT 9999 // CLR 11/07 A3...        NaN
# 4      KQEP 111140Z AUTO 00000KT 9999 CLR 09/07 A3026...        NaN
# ...                                                  ...        ...
# 13477  KIJD 111219Z AUTO 00000KT 3/4SM BR VV002 05/05...        NaN
# 13478  KFME 111219Z AUTO 00000KT 10SM CLR 04/03 A3038...        NaN
# 13479  PAIM 111219Z AUTO 27003KT 10SM OVC031 M04/M09 ...        NaN
# 13480  ETSN 111219Z 01001KT 9999 FEW018 BKN030 16/12 ...        NaN
# 13481  KRGA 111219Z AUTO 00000KT 10SM CLR 04/04 A3032...        NaN
#
# [13482 rows x 32 columns]
