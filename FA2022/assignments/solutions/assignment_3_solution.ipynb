# %% [markdown]
# # Assignment #3
#
# This assignment can be completed by adding code to this notebook for each question.
#
# Turn in a completed notebook, renamed as
#
# `assignment3_<username>.ipynb`
#
# with your `<username>` being your DataVU login name (e.g., mine is `kgoebber`) to `/archive/courses/met290/assignment3` via the Linux computing system.
#
# **DUE DATE: 8 October 2021 at 4 pm.**
#
# Prior to turning in your notebook, please cleanup and comment your code for each problem. Be sure that your output is self-describing

# %% [markdown]
# ## Question #1
# (10 points) Write Python code that will read in the pressures from a file called **hw3_pressures.dat** and
#
# a) Compute the average from a radnom sample of 100 values from your file. The file contains 500 values and you should choose 100 of the 500 to complete this problem.
#
# b) Print the average pressure and alert for High, Low, or Normal Pressure given:
#   - If the average of the pressures is greater than 1016 hPa alert that pressure is high
#   - If the average of the pressures is lower than 1004 hPa alter that the pressure is low
#   - Otherwise alert that the pressure is normal.
#
# Pressures in the file are in hPa.
#
# File is located in `/archive/courses/met330/hw3_pressures.dat`
#
# Input:
# * Pressures from the file
#
# Output:
# * The average of the 100 randomnly chosen pressures
# * The appropriate alert based on the average of the pressures
#
# Notes:
# * Make sure documentation (e.g., comment block and comments throughout code) is present in your source code
# * Be sure to use the functionality from NumPy to help randomly select the pressure values.
# * Break the problem down and complete simpler tasks first and work toward putting it all together.
# * Make output informative so that anyone running your program understand what is being produced without seeing the assignment.
# * Have all of your code for this problem contained in one cell when you turn it in

# %%
import numpy as np

pressures = np.loadtxt('hw3_pressures.dat')

r100 = np.random.randint(pressures.size, size=100)

avg_pressure = pressures[r100].mean()

print(f'The average pressure is {avg_pressure:.2f}')
if avg_pressure >= 1020:
    print('Alert: High Pressure')
elif avg_pressure < 1000:
    print('Alert: Low Pressure')
else:
    print('Pressure is normal')
# Out:
# The average pressure is 989.28
# Alert: Low Pressure

# %% [markdown]
# ## Question #2
# (20 points) Read in a dataset that contains a number of latitude/longitude pairs in each row and write Python code to calculate the great circle distance between two latitude/longitude points and find the largest and smallest distances from the location pairs in the file.
#
# The great circle distance can be calculated in the following manner using the haversine formula:
#
# $a =  sin^2(\Delta \phi / 2) + cos \phi_1 * cos \phi_2 * sin^2(\Delta \lambda/2)$
#
# $\Delta \phi = (\phi_2 - \phi_1) $
#
# $\Delta \lambda = (\lambda_2 - \lambda_1) $
#
# $c = 2 * atan2(\sqrt{a}, \sqrt{1-a})$
#
# $d = R * c $
#
# where d is the distance bewtween the two points, $\phi$ is latitude, $\lambda$ is longitude, R is earth’s radius (mean radius = 6,371km);
# note that angles need to be in radians to pass to trig functions!
#
# Notes:
# * There are Numpy functions to help you convert from degrees to radians.
# * $sin^2(x)$ is equivalent to saying $(sin(x))^2$
# * Have all of your code for this problem contained in one cell when you turn it in
#
# Input:
# * Latitude/Longitude points from `destination_locations.txt` (Available in `/archive/courses/met330/`)
#
# Output:
# * Original Latitude/Longitude Points and the Distance in kilometers between them for each latitude/longitude pair
# * Identify and print out the shortest and longest distances between points in the dataset.
#
# ```
# Example Calculation #1:
#
# Lat1/Lon1: 42.3/-101.3
#
# Lat2/Lon2: 39.35/-87.1
#
# Distance: 1237 km
#
#
# Example Calculation #2:
#
# Lat1/Lon1: 52.3/0.5
#
# Lat2/Lon2: 42.5/-88.1
#
# Distance: 6331 km
# ```

# %%
# Test latitude/longitude points
#lat1, lon1, lat2, lon2 = 52.3, 0.5, 42.5, -88.1


def great_circle_distance(lat1, lon1, lat2, lon2):
    '''This function computes the great circle distance between two latitude/longitude points.
    
    Uses the haversine version of the great circule calculation to do the computation.
    
    Input: Lat1 - Latitude of the first location
           Lon1 - Longitude of the first location
           Lat2 - Latitude of the second location
           Lon2 - Longitude of the second location
           
    Output: d - the great circle distance
    '''
    # Convert Degrees to Radians
    rad_lat1 = np.deg2rad(lat1)
    rad_lat2 = np.deg2rad(lat2)
    rad_lon1 = np.deg2rad(lon1)
    rad_lon2 = np.deg2rad(lon2)

    a = np.sin((rad_lat2-rad_lat1)/2)**2 + np.cos(rad_lat1) * np.cos(rad_lat2) * np.sin((rad_lon2 - rad_lon1)/2)**2

    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))

    R = 6371

    d = R * c
    
    return d

locs = np.loadtxt('destination_locations.txt', skiprows=1, delimiter=',')

lat1_locs = locs[:, 0]
lon1_locs = locs[:, 1]
lat2_locs = locs[:, 2]
lon2_locs = locs[:, 3]

dist = great_circle_distance(lat1_locs, lon1_locs, lat2_locs, lon2_locs)

max_dist = np.max(dist)
min_dist = np.min(dist)

for i in range(locs.shape[0]):
    print(f'Lat1: {lat1_locs[i]:6.2f}  Lon1: {lon1_locs[i]:7.2f}   Lat2: {lat2_locs[i]:6.2f} '
          f'Lon2: {lon2_locs[i]:7.2f}  Distance: {dist[i]:.2f} km')
print(f'Maximum distance between two locations in file: {max_dist:.2f} km')
print(f'Minimum distance between two locations in file: {min_dist:.2f} km')
# Out:
# Lat1:  46.31  Lon1:  131.44   Lat2: -23.01 Lon2:  -55.86  Distance: 17342.46 km
# Lat1:  -6.10  Lon1:   15.62   Lat2: -87.18 Lon2:   29.22  Distance: 9024.53 km
# Lat1: -10.29  Lon1:  -85.23   Lat2: -32.66 Lon2: -125.70  Distance: 4826.00 km
# Lat1:  38.71  Lon1:   47.37   Lat2:  22.66 Lon2:  -84.76  Distance: 11565.51 km
# Lat1:  45.25  Lon1: -137.50   Lat2:  34.86 Lon2: -145.22  Distance: 1327.60 km
# Lat1:  11.38  Lon1:   71.31   Lat2: -13.75 Lon2:  122.37  Distance: 6285.14 km
# Lat1: -89.62  Lon1:  136.08   Lat2:   8.14 Lon2:  -51.18  Distance: 10954.59 km
# Lat1:  13.18  Lon1:   23.22   Lat2: -44.50 Lon2:  172.35  Distance: 15467.62 km
# Lat1: -45.45  Lon1: -155.57   Lat2:  42.29 Lon2:   21.44  Distance: 19589.82 km
# Lat1: -76.74  Lon1:    8.40   Lat2: -15.44 Lon2:  137.74  Distance: 9247.75 km
# Lat1:  -4.36  Lon1: -164.98   Lat2:  62.62 Lon2:  -76.08  Distance: 10381.76 km
# Lat1: -57.31  Lon1:   29.17   Lat2:  -4.82 Lon2:   99.14  Distance: 8364.46 km
# Lat1:  54.69  Lon1: -135.04   Lat2: -41.43 Lon2:   -3.40  Distance: 16221.78 km
# Lat1:  75.37  Lon1:  108.23   Lat2:   7.35 Lon2: -108.70  Distance: 10495.15 km
# Lat1:  78.56  Lon1:   75.36   Lat2:  15.22 Lon2: -177.32  Distance: 8722.52 km
# Lat1: -49.37  Lon1:  -72.58   Lat2: -72.61 Lon2:   72.08  Distance: 6178.44 km
# Lat1:  15.50  Lon1:   -0.62   Lat2: -68.45 Lon2:   47.55  Distance: 10087.17 km
# Lat1:  63.65  Lon1:   74.43   Lat2: -21.21 Lon2:   35.27  Distance: 10028.90 km
# Lat1: -40.06  Lon1: -178.08   Lat2: -62.94 Lon2:  141.47  Distance: 3676.16 km
# Lat1: -72.69  Lon1:   53.42   Lat2:  11.31 Lon2:   69.67  Distance: 9415.00 km
# Lat1:  27.84  Lon1: -106.05   Lat2: -50.70 Lon2:  -83.41  Distance: 9012.65 km
# Lat1:   2.69  Lon1:  -53.03   Lat2: -60.76 Lon2:  132.77  Distance: 13539.26 km
# Lat1: -45.90  Lon1: -159.85   Lat2:  52.27 Lon2: -103.70  Distance: 12155.24 km
# Lat1:  -0.52  Lon1:   67.25   Lat2: -56.22 Lon2:  -26.20  Distance: 10172.66 km
# Lat1:  38.90  Lon1:  131.33   Lat2:  52.66 Lon2: -103.50  Distance: 8546.21 km
# Lat1: -75.27  Lon1:   13.77   Lat2:  71.05 Lon2: -155.88  Distance: 19441.17 km
# Lat1:  79.99  Lon1: -172.49   Lat2: -32.74 Lon2:   55.17  Distance: 14358.49 km
# Lat1:  46.95  Lon1:  -65.88   Lat2:  67.63 Lon2:   32.95  Distance: 5616.94 km
# Lat1: -80.56  Lon1:  -78.59   Lat2:   8.43 Lon2:   19.61  Distance: 11081.40 km
# Lat1:  40.63  Lon1: -159.79   Lat2: -59.86 Lon2:  -89.80  Distance: 12858.74 km
# Lat1:  89.53  Lon1: -108.02   Lat2:  87.11 Lon2:   34.09  Distance: 364.01 km
# Lat1: -84.16  Lon1:   53.75   Lat2: -44.12 Lon2:  125.62  Distance: 4929.70 km
# Lat1: -65.11  Lon1:  118.02   Lat2: -11.53 Lon2:   55.38  Distance: 7587.12 km
# Lat1:  17.57  Lon1:   78.25   Lat2:  72.24 Lon2: -158.09  Distance: 9200.70 km
# Lat1: -15.61  Lon1:   41.49   Lat2:  22.51 Lon2:   45.54  Distance: 4261.63 km
# Lat1:  44.69  Lon1:   32.32   Lat2:  -5.62 Lon2:  -48.48  Distance: 9725.56 km
# Lat1: -32.19  Lon1:  -76.79   Lat2: -26.11 Lon2:  -62.85  Distance: 1511.35 km
# Lat1:  22.53  Lon1: -137.38   Lat2:  -3.79 Lon2: -177.02  Distance: 5205.10 km
# Lat1:   7.29  Lon1:  144.45   Lat2:  27.52 Lon2:  -12.26  Distance: 15404.47 km
# Lat1: -71.41  Lon1: -110.36   Lat2:   5.21 Lon2:   65.66  Distance: 12648.65 km
# Lat1:  36.23  Lon1:   96.82   Lat2:  78.91 Lon2:    6.86  Distance: 6064.84 km
# Lat1:  70.14  Lon1: -105.61   Lat2: -34.21 Lon2:  120.45  Distance: 15162.99 km
# Lat1:  86.91  Lon1:  120.35   Lat2: -48.91 Lon2:  -62.63  Distance: 15789.18 km
# Lat1:  24.29  Lon1:   98.13   Lat2: -48.57 Lon2: -150.75  Distance: 13534.43 km
# Lat1:  46.18  Lon1:  -72.26   Lat2:  35.07 Lon2: -108.12  Distance: 3234.84 km
# Lat1:  14.25  Lon1:  -75.97   Lat2: -22.52 Lon2:  -34.08  Distance: 6126.22 km
# Lat1:  86.77  Lon1:  -10.65   Lat2: -74.37 Lon2: -127.23  Distance: 18406.24 km
# Lat1: -41.02  Lon1:  134.00   Lat2:  57.53 Lon2:  107.28  Distance: 11237.94 km
# Lat1: -40.85  Lon1:   74.20   Lat2:  69.84 Lon2:    0.67  Distance: 13642.53 km
# Lat1:  50.17  Lon1:   59.45   Lat2:  69.75 Lon2: -161.22  Distance: 6279.48 km
# Lat1:   2.64  Lon1:  -71.31   Lat2:  15.16 Lon2:  -95.92  Distance: 3035.33 km
# Lat1: -36.47  Lon1:  -83.41   Lat2:  15.40 Lon2:   89.24  Distance: 17561.79 km
# Lat1:  -0.81  Lon1:  -55.48   Lat2:  50.43 Lon2:  -49.47  Distance: 5726.18 km
# Lat1:  12.47  Lon1:  -58.98   Lat2:  35.72 Lon2: -107.50  Distance: 5490.01 km
# Lat1: -18.55  Lon1: -102.31   Lat2:  40.91 Lon2:   72.24  Distance: 17475.08 km
# Lat1: -69.07  Lon1:   66.02   Lat2: -12.85 Lon2:  168.71  Distance: 9169.15 km
# Lat1: -34.97  Lon1:  120.77   Lat2:  -6.60 Lon2: -167.43  Distance: 7931.49 km
# Lat1: -55.74  Lon1:  147.79   Lat2:  74.98 Lon2:   34.02  Distance: 16566.70 km
# Lat1:  54.21  Lon1: -113.30   Lat2: -63.03 Lon2:   81.56  Distance: 18716.67 km
# Lat1:  63.79  Lon1: -117.99   Lat2:  22.83 Lon2:    2.57  Distance: 9105.34 km
# Lat1:  60.85  Lon1:   53.48   Lat2:  65.87 Lon2: -149.26  Distance: 5800.53 km
# Lat1:  -9.74  Lon1:   97.80   Lat2:  55.71 Lon2:  -41.68  Distance: 13808.78 km
# Lat1:  -7.20  Lon1:  -79.91   Lat2:  68.68 Lon2:  -78.47  Distance: 8438.22 km
# Lat1:  72.77  Lon1:   82.31   Lat2:  67.17 Lon2:  139.43  Distance: 2167.35 km
# Lat1: -59.93  Lon1:   -5.25   Lat2: -60.88 Lon2:  -63.58  Distance: 3098.50 km
# Lat1: -42.16  Lon1:  128.11   Lat2:  25.30 Lon2:  160.45  Distance: 8203.63 km
# Lat1:  34.90  Lon1:  104.14   Lat2:  48.49 Lon2:   34.81  Distance: 5744.44 km
# Lat1:  49.17  Lon1:  142.49   Lat2: -25.04 Lon2:  -46.32  Distance: 17225.03 km
# Lat1:   6.79  Lon1:  -18.57   Lat2:  26.75 Lon2:  173.74  Distance: 16056.68 km
# Lat1:  52.44  Lon1:   -4.02   Lat2:   3.83 Lon2: -158.37  Distance: 13309.18 km
# Lat1: -16.66  Lon1:  164.99   Lat2: -14.61 Lon2:   97.70  Distance: 7174.15 km
# Lat1:  81.22  Lon1:  155.65   Lat2: -77.62 Lon2: -124.19  Distance: 18200.42 km
# Lat1: -21.31  Lon1:   61.59   Lat2:  35.45 Lon2:  167.02  Distance: 12717.85 km
# Lat1:  30.98  Lon1:  115.62   Lat2: -14.98 Lon2:   14.27  Distance: 11922.34 km
# Lat1: -87.08  Lon1: -163.02   Lat2:  13.17 Lon2:  -10.60  Distance: 11759.33 km
# Lat1: -19.11  Lon1:  -59.24   Lat2: -43.82 Lon2:   43.89  Distance: 9549.65 km
# Lat1:  15.65  Lon1:    8.63   Lat2: -33.53 Lon2:  120.93  Distance: 13006.98 km
# Lat1:  71.33  Lon1:   56.71   Lat2: -76.71 Lon2: -118.21  Distance: 19397.53 km
# Lat1:  84.00  Lon1: -170.87   Lat2: -61.74 Lon2:   57.84  Distance: 17270.60 km
# Lat1:  38.14  Lon1:   94.22   Lat2:  67.29 Lon2:  -27.28  Distance: 7308.75 km
# Lat1:  64.15  Lon1:  -83.41   Lat2:  37.36 Lon2:  137.20  Distance: 8179.53 km
# Lat1: -70.42  Lon1:  146.05   Lat2:  59.91 Lon2:   27.54  Distance: 17075.11 km
# Lat1: -84.99  Lon1:  -78.15   Lat2:  80.05 Lon2: -167.36  Distance: 18770.77 km
# Lat1:  71.99  Lon1: -153.12   Lat2: -45.83 Lon2: -143.87  Distance: 13121.18 km
# Lat1:  52.17  Lon1:  126.07   Lat2:  32.76 Lon2:   38.12  Distance: 7063.38 km
# Lat1:   2.77  Lon1:  -34.90   Lat2:  -6.12 Lon2:   30.15  Distance: 7289.65 km
# Lat1:  81.91  Lon1:   19.33   Lat2:  58.63 Lon2: -158.18  Distance: 4387.06 km
# Lat1:  20.57  Lon1:  131.17   Lat2:  73.19 Lon2:   93.51  Distance: 6292.07 km
# Lat1:  79.54  Lon1:  -36.66   Lat2: -82.37 Lon2:    0.81  Distance: 18108.26 km
# Lat1: -55.31  Lon1:  -44.10   Lat2: -34.30 Lon2:  -92.06  Distance: 4325.93 km
# Lat1: -29.22  Lon1:  109.87   Lat2:  11.84 Lon2:  165.77  Distance: 7532.91 km
# Lat1:  78.46  Lon1:  107.18   Lat2: -47.33 Lon2:  154.36  Distance: 14335.34 km
# Lat1: -31.37  Lon1: -153.20   Lat2:  84.28 Lon2: -103.56  Distance: 13073.40 km
# Lat1:  28.99  Lon1:   76.99   Lat2:   7.53 Lon2:  -10.17  Distance: 9327.89 km
# Lat1: -61.48  Lon1:  -89.94   Lat2: -71.39 Lon2:  137.18  Distance: 4803.10 km
# Lat1:  84.69  Lon1:   21.28   Lat2:  71.52 Lon2:  108.76  Distance: 2110.05 km
# Lat1: -39.73  Lon1:  -11.81   Lat2: -71.60 Lon2:  -38.16  Distance: 3837.35 km
# Lat1: -16.37  Lon1: -125.39   Lat2: -42.58 Lon2: -143.44  Distance: 3381.60 km
# Lat1:  -8.31  Lon1:   65.58   Lat2: -63.30 Lon2:   67.32  Distance: 6116.20 km
# Lat1:  24.26  Lon1:  -80.75   Lat2: -59.22 Lon2:   95.88  Distance: 16118.75 km
# Maximum distance between two locations in file: 19589.82 km
# Minimum distance between two locations in file: 364.01 km

# %% [markdown]
# ## Question #3
# (20 points) Write Python code to determine the average, maximum, and minimum SOI for each year. Also determine the months that the standardized Southern Oscillation Index (SOI) indicate El Nino conditions (for simplicity defined for this assignment as SOI < -1.25) or La Nina conditions (for simplicity defined for this assignment as SOI > 1.25) by reporting the month, year, and SOI value along with the designation of El Nino or La Nina. Additionally, determine the maximum and minimum value SOI over the entire period, reporting the month and year they occurred in. Print the results to the screen.
#
# Input File: soi_data.txt (Available in */archive/courses/met290*)
#
# Output:
# * The average SOI value for each year
# * The maximum SOI value for each year
# * The minimum SOI value for each year
# * Month, Year, and SOI values for El Nino and La Nina Months
# * The total number of months spent in La Nina for the dataset
# * The total number of months spent in El Nino for the dataset
#
# **Background**
#
# The Southern Oscillation Index (SOI) is a measure of the difference between sea level pressure in Tahiti and Darwin, Australian, which gives a proxy for shifts in the Walker Circulation and thus the El Nino – Southern Oscillation (ENSO). There are many other ways to define ENSO periods and a good resource for background information can be found at: https://www.climate.gov/news-features/blogs/enso/why-are-there-so-many-enso-indexes-instead-just-one.
#
# Generally, an El Nino or La Nina event cannot be determined from any one month of an ENSO index, however, for simplicity here we define an El Nino event when the SOI value is below -1.25 for any particular month and a La Nina event when the SOI value is above 1.25 for any particular month.
#
# Notes:
# * Break the problem down into smaller bite size pieces. For example, first write your program to be able to read in the input file and separate out the year column from the SOI data columns. Then work to find the global max and min values. Then work on finding individual months that can be classified as El Nino, etc.
# * Make sure to regularly save your work.
# * Be sure to verify that your results are correct.
#
# Please make your program to produce output in the same fashion as the test cases below.
#
# Example Output (Fake Data)
#
# \>>>
#
# Year  Max SOI  Avg. SOI  Min SOI
#
# 2024    1.34      0.45    -1.12
#
# 2025    0.98      0.03    -2.10
#
# .
#
# .
#
# .
#
#
# El Nino: February 2020
#
# SOI: -3.5
#
#
# La Nina: July 2021
#
# SOI: 1.4
#
# .
#
# .
#
# .
#
# .
#
# Max SOI of 2.2 in October 2050
#
# Min SOI of -3.1 in December 2024
#
# Number of La Nina Months: 25
#
# Number of El Nino Months: 33
#
# \>>>

# %%
soi = np.loadtxt('soi_data.txt', skiprows=4)

soi_years = soi[:, 0].astype('int')
soi_data = soi[:, 1:]

avg_soi_year = soi_data.mean(axis=1)
max_soi_year = soi_data.max(axis=1)
min_soi_year = soi_data.min(axis=1)

number_el = soi_data[soi_data < -1.25].size
number_la = soi_data[soi_data > 1.25].size

max_data = np.max(soi_data)
min_data = np.min(soi_data)

max_ind = np.where(soi_data == max_data)
min_ind = np.where(soi_data == min_data)

months = ['January', 'February', 'March', 'April', 'May', 'June',
          'July', 'August', 'September', 'October', 'November', 'December']

print(' Year   Max SOI  Avg. SOI  Min SOI')
for i, year in enumerate(soi_years):
    print(f' {year}   {max_soi_year[i]:7.2f}  {avg_soi_year[i]:7.2f}  {min_soi_year[i]:7.2f}')
    
print()

for year in range(soi_data.shape[0]):
    for month in range(soi_data.shape[1]):
        if soi_data[year, month] > 1.25:
            print(f'La Nina Conditions: {months[month]} {soi_years[year]}')
            print(f' SOI Value: {soi_data[year, month]}')
            print()
        elif soi_data[year, month] < -1.25:
            print(f'El Nino Conditions: {months[month]} {soi_years[year]}')
            print(f' SOI Value: {soi_data[year, month]}')
            print()
            
print()
print(f'Max SOI in dataset: {soi_data[max_ind[0][0], max_ind[1][0]]} occurred {months[max_ind[1][0]]} {soi_years[max_ind[0][0]]}')
print(f'Min SOI in dataset: {soi_data[min_ind[0][0], min_ind[1][0]]} occurred {months[min_ind[1][0]]} {soi_years[min_ind[0][0]]}')
print()
print(f'Number of El Nino Months: {number_el}')
print(f'Number of La Nina Monhts: {number_la}')
# Out:
#  Year   Max SOI  Avg. SOI  Min SOI
#  1951      1.50    -0.27    -1.10
#  1952      0.80    -0.01    -1.20
#  1953      0.30    -0.41    -1.70
#  1954      1.40     0.45    -0.30
#  1955      1.90     1.03    -0.50
#  1956      1.80     1.09     0.10
#  1957      0.60    -0.17    -1.00
#  1958      0.90    -0.15    -1.90
#  1959      1.30     0.14    -1.40
#  1960      1.00     0.50     0.10
#  1961      1.50     0.18    -1.80
#  1962      2.00     0.53    -0.30
#  1963      1.10    -0.04    -1.20
#  1964      1.50     0.62    -0.40
#  1965      0.80    -0.51    -1.80
#  1966      0.60    -0.22    -1.30
#  1967      1.70     0.47    -0.60
#  1968      1.30     0.39    -0.30
#  1969      0.40    -0.35    -1.50
#  1970      1.90     0.47    -1.10
#  1971      2.30     1.11     0.20
#  1972      1.10    -0.48    -1.60
#  1973      2.60     0.74    -1.40
#  1974      2.40     1.10    -0.10
#  1975      2.10     1.33    -0.50
#  1976      1.70     0.32    -1.10
#  1977      1.20    -0.63    -1.30
#  1978      1.40    -0.07    -2.70
#  1979      1.30     0.14    -0.70
#  1980      0.40    -0.07    -0.60
#  1981      1.20     0.24    -1.30
#  1982      1.20    -0.88    -2.60
#  1983      0.90    -0.76    -3.60
#  1984      0.90     0.14    -0.30
#  1985      1.20     0.28    -0.40
#  1986      1.00    -0.08    -1.40
#  1987      0.00    -0.93    -1.40
#  1988      1.80     0.82    -0.40
#  1989      1.60     0.71    -0.50
#  1990      1.20    -0.12    -1.80
#  1991      0.60    -0.58    -1.80
#  1992      0.40    -0.82    -2.90
#  1993      0.20    -0.65    -1.20
#  1994      0.30    -0.82    -1.60
#  1995      0.80    -0.02    -0.70
#  1996      1.20     0.67    -0.10
#  1997      1.70    -0.73    -1.50
#  1998      1.40    -0.02    -2.70
#  1999      1.80     0.85    -0.10
#  2000      1.80     0.85    -0.20
#  2001      1.70     0.26    -0.80
#  2002      1.10    -0.33    -1.10
#  2003      1.10    -0.09    -0.70
#  2004      1.20    -0.26    -1.30
#  2005      1.20    -0.18    -3.10
#  2006      1.80     0.03    -1.30
#  2007      1.70     0.27    -0.80
#  2008      2.60     1.13    -0.10
#  2009      1.90     0.17    -1.20
#  2010      2.90     0.91    -1.50
#  2011      2.70     1.40     0.20
#  2012      1.10     0.13    -0.60
#  2013      1.50     0.45    -0.20
#  2014      1.40    -0.13    -0.90
#  2015      0.20    -0.79    -1.70
#  2016      1.20    -0.19    -2.20
#
# La Nina Conditions: January 1951
#  SOI Value: 1.5
#
# El Nino Conditions: May 1953
#  SOI Value: -1.7
#
# La Nina Conditions: December 1954
#  SOI Value: 1.4
#
# La Nina Conditions: February 1955
#  SOI Value: 1.9
#
# La Nina Conditions: June 1955
#  SOI Value: 1.3
#
# La Nina Conditions: July 1955
#  SOI Value: 1.6
#
# La Nina Conditions: August 1955
#  SOI Value: 1.5
#
# La Nina Conditions: September 1955
#  SOI Value: 1.3
#
# La Nina Conditions: October 1955
#  SOI Value: 1.5
#
# La Nina Conditions: January 1956
#  SOI Value: 1.3
#
# La Nina Conditions: February 1956
#  SOI Value: 1.6
#
# La Nina Conditions: March 1956
#  SOI Value: 1.3
#
# La Nina Conditions: May 1956
#  SOI Value: 1.4
#
# La Nina Conditions: October 1956
#  SOI Value: 1.8
#
# El Nino Conditions: January 1958
#  SOI Value: -1.9
#
# El Nino Conditions: February 1959
#  SOI Value: -1.4
#
# La Nina Conditions: March 1959
#  SOI Value: 1.3
#
# El Nino Conditions: March 1961
#  SOI Value: -1.8
#
# La Nina Conditions: December 1961
#  SOI Value: 1.5
#
# La Nina Conditions: January 1962
#  SOI Value: 2.0
#
# La Nina Conditions: August 1964
#  SOI Value: 1.5
#
# La Nina Conditions: September 1964
#  SOI Value: 1.3
#
# La Nina Conditions: October 1964
#  SOI Value: 1.3
#
# El Nino Conditions: July 1965
#  SOI Value: -1.8
#
# El Nino Conditions: September 1965
#  SOI Value: -1.3
#
# El Nino Conditions: November 1965
#  SOI Value: -1.5
#
# El Nino Conditions: January 1966
#  SOI Value: -1.3
#
# La Nina Conditions: January 1967
#  SOI Value: 1.7
#
# La Nina Conditions: February 1967
#  SOI Value: 1.7
#
# La Nina Conditions: February 1968
#  SOI Value: 1.3
#
# El Nino Conditions: January 1969
#  SOI Value: -1.5
#
# La Nina Conditions: November 1970
#  SOI Value: 1.6
#
# La Nina Conditions: December 1970
#  SOI Value: 1.9
#
# La Nina Conditions: February 1971
#  SOI Value: 2.0
#
# La Nina Conditions: March 1971
#  SOI Value: 2.3
#
# La Nina Conditions: April 1971
#  SOI Value: 1.7
#
# La Nina Conditions: August 1971
#  SOI Value: 1.5
#
# La Nina Conditions: September 1971
#  SOI Value: 1.4
#
# La Nina Conditions: October 1971
#  SOI Value: 1.7
#
# El Nino Conditions: May 1972
#  SOI Value: -1.6
#
# El Nino Conditions: July 1972
#  SOI Value: -1.4
#
# El Nino Conditions: September 1972
#  SOI Value: -1.4
#
# El Nino Conditions: December 1972
#  SOI Value: -1.3
#
# El Nino Conditions: February 1973
#  SOI Value: -1.4
#
# La Nina Conditions: August 1973
#  SOI Value: 1.3
#
# La Nina Conditions: November 1973
#  SOI Value: 2.6
#
# La Nina Conditions: December 1973
#  SOI Value: 1.8
#
# La Nina Conditions: January 1974
#  SOI Value: 2.4
#
# La Nina Conditions: February 1974
#  SOI Value: 2.1
#
# La Nina Conditions: March 1974
#  SOI Value: 2.4
#
# La Nina Conditions: March 1975
#  SOI Value: 1.6
#
# La Nina Conditions: June 1975
#  SOI Value: 1.3
#
# La Nina Conditions: July 1975
#  SOI Value: 1.9
#
# La Nina Conditions: August 1975
#  SOI Value: 2.0
#
# La Nina Conditions: September 1975
#  SOI Value: 2.1
#
# La Nina Conditions: October 1975
#  SOI Value: 1.7
#
# La Nina Conditions: December 1975
#  SOI Value: 2.1
#
# La Nina Conditions: January 1976
#  SOI Value: 1.4
#
# La Nina Conditions: February 1976
#  SOI Value: 1.7
#
# La Nina Conditions: March 1976
#  SOI Value: 1.7
#
# El Nino Conditions: November 1977
#  SOI Value: -1.3
#
# El Nino Conditions: February 1978
#  SOI Value: -2.7
#
# La Nina Conditions: May 1978
#  SOI Value: 1.4
#
# La Nina Conditions: July 1979
#  SOI Value: 1.3
#
# El Nino Conditions: March 1981
#  SOI Value: -1.3
#
# El Nino Conditions: July 1982
#  SOI Value: -1.5
#
# El Nino Conditions: August 1982
#  SOI Value: -1.7
#
# El Nino Conditions: September 1982
#  SOI Value: -1.7
#
# El Nino Conditions: October 1982
#  SOI Value: -1.7
#
# El Nino Conditions: November 1982
#  SOI Value: -2.6
#
# El Nino Conditions: December 1982
#  SOI Value: -2.2
#
# El Nino Conditions: January 1983
#  SOI Value: -3.5
#
# El Nino Conditions: February 1983
#  SOI Value: -3.6
#
# El Nino Conditions: March 1983
#  SOI Value: -2.4
#
# El Nino Conditions: December 1986
#  SOI Value: -1.4
#
# El Nino Conditions: March 1987
#  SOI Value: -1.3
#
# El Nino Conditions: April 1987
#  SOI Value: -1.4
#
# El Nino Conditions: May 1987
#  SOI Value: -1.3
#
# El Nino Conditions: July 1987
#  SOI Value: -1.4
#
# La Nina Conditions: August 1988
#  SOI Value: 1.5
#
# La Nina Conditions: September 1988
#  SOI Value: 1.8
#
# La Nina Conditions: October 1988
#  SOI Value: 1.4
#
# La Nina Conditions: November 1988
#  SOI Value: 1.7
#
# La Nina Conditions: January 1989
#  SOI Value: 1.5
#
# La Nina Conditions: April 1989
#  SOI Value: 1.6
#
# El Nino Conditions: February 1990
#  SOI Value: -1.8
#
# El Nino Conditions: September 1991
#  SOI Value: -1.5
#
# El Nino Conditions: December 1991
#  SOI Value: -1.8
#
# El Nino Conditions: January 1992
#  SOI Value: -2.9
#
# El Nino Conditions: March 1992
#  SOI Value: -2.0
#
# El Nino Conditions: October 1992
#  SOI Value: -1.4
#
# El Nino Conditions: April 1994
#  SOI Value: -1.3
#
# El Nino Conditions: July 1994
#  SOI Value: -1.3
#
# El Nino Conditions: September 1994
#  SOI Value: -1.6
#
# La Nina Conditions: February 1997
#  SOI Value: 1.7
#
# El Nino Conditions: May 1997
#  SOI Value: -1.3
#
# El Nino Conditions: June 1997
#  SOI Value: -1.4
#
# El Nino Conditions: August 1997
#  SOI Value: -1.4
#
# El Nino Conditions: September 1997
#  SOI Value: -1.4
#
# El Nino Conditions: October 1997
#  SOI Value: -1.5
#
# El Nino Conditions: January 1998
#  SOI Value: -2.7
#
# El Nino Conditions: February 1998
#  SOI Value: -2.0
#
# El Nino Conditions: March 1998
#  SOI Value: -2.4
#
# El Nino Conditions: April 1998
#  SOI Value: -1.4
#
# La Nina Conditions: December 1998
#  SOI Value: 1.4
#
# La Nina Conditions: January 1999
#  SOI Value: 1.8
#
# La Nina Conditions: March 1999
#  SOI Value: 1.3
#
# La Nina Conditions: April 1999
#  SOI Value: 1.4
#
# La Nina Conditions: December 1999
#  SOI Value: 1.4
#
# La Nina Conditions: February 2000
#  SOI Value: 1.7
#
# La Nina Conditions: March 2000
#  SOI Value: 1.3
#
# La Nina Conditions: November 2000
#  SOI Value: 1.8
#
# La Nina Conditions: February 2001
#  SOI Value: 1.7
#
# El Nino Conditions: January 2004
#  SOI Value: -1.3
#
# El Nino Conditions: February 2005
#  SOI Value: -3.1
#
# La Nina Conditions: January 2006
#  SOI Value: 1.7
#
# La Nina Conditions: March 2006
#  SOI Value: 1.8
#
# El Nino Conditions: October 2006
#  SOI Value: -1.3
#
# La Nina Conditions: December 2007
#  SOI Value: 1.7
#
# La Nina Conditions: January 2008
#  SOI Value: 1.8
#
# La Nina Conditions: February 2008
#  SOI Value: 2.6
#
# La Nina Conditions: March 2008
#  SOI Value: 1.4
#
# La Nina Conditions: October 2008
#  SOI Value: 1.3
#
# La Nina Conditions: November 2008
#  SOI Value: 1.3
#
# La Nina Conditions: December 2008
#  SOI Value: 1.4
#
# La Nina Conditions: February 2009
#  SOI Value: 1.9
#
# El Nino Conditions: February 2010
#  SOI Value: -1.5
#
# La Nina Conditions: July 2010
#  SOI Value: 1.8
#
# La Nina Conditions: August 2010
#  SOI Value: 1.8
#
# La Nina Conditions: September 2010
#  SOI Value: 2.2
#
# La Nina Conditions: October 2010
#  SOI Value: 1.7
#
# La Nina Conditions: November 2010
#  SOI Value: 1.3
#
# La Nina Conditions: December 2010
#  SOI Value: 2.9
#
# La Nina Conditions: January 2011
#  SOI Value: 2.3
#
# La Nina Conditions: February 2011
#  SOI Value: 2.7
#
# La Nina Conditions: March 2011
#  SOI Value: 2.5
#
# La Nina Conditions: April 2011
#  SOI Value: 1.9
#
# La Nina Conditions: December 2011
#  SOI Value: 2.5
#
# La Nina Conditions: March 2013
#  SOI Value: 1.5
#
# La Nina Conditions: January 2014
#  SOI Value: 1.4
#
# El Nino Conditions: August 2015
#  SOI Value: -1.4
#
# El Nino Conditions: September 2015
#  SOI Value: -1.6
#
# El Nino Conditions: October 2015
#  SOI Value: -1.7
#
# El Nino Conditions: January 2016
#  SOI Value: -2.2
#
# El Nino Conditions: February 2016
#  SOI Value: -2.0
#
#
# Max SOI in dataset: 2.9 occurred December 2010
# Min SOI in dataset: -3.6 occurred February 1983
#
# Number of El Nino Months: 58
# Number of La Nina Monhts: 87
